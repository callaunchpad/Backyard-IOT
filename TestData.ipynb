# %%
import numpy as np

import matplotlib.pyplot as plt

import random

# %%
images = np.load('small_images.npy')
labels = np.load('small_labels.npy')
convert = np.load('label_to_animal.npz')

# %%
print('images', images.shape)
print('labels', labels.shape)
# Out:
# images (1000, 384, 512, 3)
# labels (1000, 16)

# %%
convert = dict(convert)['arr_0']

# %%
choice = random.randint(0, images.shape[0])

plt.imshow(images[choice].astype('float32'))
print(convert[np.argmax(labels[choice])])
print(np.max(images[choice]))
# Out:
# raccoon
# 0.996
